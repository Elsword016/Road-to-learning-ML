# %%
#canny edge detection algorithm
#simple canny edge detection

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('/content/car.jpg',0)
plt.imshow(img, cmap='gray')

# %%
img.max()
# Out:
# 255

# %%
inv = 255-img
plt.imshow(inv, cmap='gray')

# %%
blur = cv2.GaussianBlur(inv ,ksize=(21,21), sigmaX=0, sigmaY=0)
plt.imshow(blur, cmap='gray')

# %%
dodge = lambda image, mask: cv2.divide(image, 255-mask, scale=256)
blend = dodge(img, blur)
plt.imshow(blend, cmap='gray')

# %%
cv2.imwrite('sketch2.jpg', blend)
# Out:
# True
